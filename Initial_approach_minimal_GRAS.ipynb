# %% [markdown]
# # INITIAL APPROACH (WITH MINIMAL MEDIA)

# %% [markdown]
# Partimos de una lista de organismos aptos para el consumo humano, de los que deseamos comprobar si son capaces de crecer en un medio procedente de la hidrólisis del alga Ulva. Trabajaremos con aquellas especies que presentan modelos en AGORA2 o, en su defecto, que pertencen a un género con modelos en esta base de datos.

# %%
import openpyxl
import requests
import cobra
import os
from bs4 import BeautifulSoup
from cobra.io import read_sbml_model
from pathlib import Path
from cobra.medium import minimal_medium
import warnings
import json

# %% [markdown]
# ### Lectura del Excel

# %% [markdown]
# Partimos de un archivo excel con una hoja "Especies_AGORA2" con 3 columnas:
# - Especie: organismo GRAS
# - Modelo en AGORA2: indica si existen modelos de cepas de dicha especie en dicho repositorio (Y) o no (N)
# - Archivo: indica el nombre de los archivos de dichos modelos, separados por comas
#
# Existe otra hoja "Géneros AGORA_2" con los géneros a los que pertenecen los anteriores organismos GRASS, indicando lo mismo pero a nivel de género (los modelos que existen en AGORA2 para dicho género). Esto es de utilidad para los organismos para los que no exista modelo como tal.
#
# Leemos ese excel y creamos 3 listas:
# - Organismos con modelo en AGORA2
# - Organismos sin modelo en AGORA2 pero que pertenecen a un género del que existen organismos con modelo en AGORA2
# - Organismos no soportados de ninguna manera en AGORA2, de los que no se pueden extraer conclusiones

# %%
#Leemos las hojas del excel y creamos las listas
def leer_excel(file_path):
    try:
        # Cargar el libro de trabajo de Excel
        workbook = openpyxl.load_workbook(file_path)
        
        # Seleccionar las hojas a trabajar
        especies_sheet = workbook["Especies_AGORA2"]
        generos_sheet = workbook["Géneros_AGORA2"]
        
        #Creamos los diccionarios
        especies_modelos = {}
        generos_modelos = {}
        no_modelos = []
        
        # Si el organismo (columna 1) tiene modelos (Y) creamos diccionario especies_modelos
        # Si no tiene modelos se busca el género
        # Si el género tiene modelos se añade al diccionario generos_modelos
        #Si no tiene nada se añade a la lista no_modelos
        for i, celda in enumerate(especies_sheet["B"][1:]):
            i = i+1 #para que corresponda con el numero de la fila
            nombre_especie = especies_sheet["A"][i].value
            if celda.value == "Y":
                modelos = especies_sheet["C"][i].value.split(",")
                especies_modelos[nombre_especie] = modelos
            else:
                #Nos quedamos con el genero y comprobamos si tiene modelos
                genero = nombre_especie.split("_")[0]
                #print(genero)
                soportado = False
                for j, gen in enumerate(generos_sheet["A"][1:]):
                    #print(gen.value)
                    j = j+1
                    if gen.value == genero and generos_sheet["B"][j].value == "Y":
                        soportado = True
                        modelos = generos_sheet["C"][j].value.split(",")
                        generos_modelos[nombre_especie] = modelos
                # Si el género no está soportado, se añade la especie a la lista de no_modelos
                if soportado == False:
                    no_modelos.append(nombre_especie)

        return especies_modelos, generos_modelos, no_modelos
    
    except Exception as e:
        print(f"Error al leer el archivo Excel: {e}")
        return None

# %% [markdown]
# ### Descarga de modelos de AGORA2

# %%
def descargar_agora2(nombre_modelo):
    nombre_modelo = nombre_modelo
    url_padre = "https://www.vmh.life/files/reconstructions/AGORA2/version2.01/sbml_files/individual_reconstructions/"
    url = url_padre + nombre_modelo
    #Directorio donde se guardan los modelos
    nombre_directorio = "modelos_agora"
    directorio_actual = os.getcwd()
    ruta_directorio = os.path.join(directorio_actual, nombre_directorio)
    #Lo creamos si no existe
    if not os.path.exists(ruta_directorio):
        os.makedirs(ruta_directorio)
        models_dir = ruta_directorio
    else:
        models_dir = ruta_directorio
    #Si ya existe el archivo no hace falta descargarlo, se importa directamente
    ruta_archivo = os.path.join(str(models_dir), nombre_modelo)
    if os.path.exists(ruta_archivo):
        file_path = Path (models_dir)/(nombre_modelo)
        file_path = file_path.resolve()
        model = read_sbml_model(str(file_path))
        return model 
    #Si no existe se descarga y se importa
    else:
        try:
            # Realizar la solicitud GET a la URL del archivo
            respuesta = requests.get(url)

            # Verificar si la solicitud fue exitosa (código de estado 200)
            if respuesta.status_code == 200:
                # Guardar el archivo localmente
                with open(ruta_archivo, 'wb') as archivo_local:
                    archivo_local.write(respuesta.content)
                #print(f"Archivo descargado exitosamente como '{nombre_modelo}'.")
                #Determinamos el path al archivo
                file_path = Path (models_dir)/(nombre_modelo)
                file_path = file_path.resolve()
                model = read_sbml_model(str(file_path))
                return model

            else:
                print(f"Error al descargar el archivo. Código de estado: {respuesta.status_code}")

        except Exception as e:
            print("Error_modelo")

# %% [markdown]
# ### Modificación de la composición del medio

# %% [markdown]
# El medio en el que deben crecer los organismos debe presentar las siguientes fuentes de carbono:
# - glucosa
# - rhamnosa
# - xylosa
# - ácido glucurónico
# - hydroxymethylfurfural (HMF)
# - furfural (poco)
#
# Sin embargo, hay que tener en cuenta las auxotrofías de los organismos, que mantendremos. Vamos a eliminar todos los metabolitos del medio que no sean estrictamente necesarios para el crecimiento (medio mínimo). Si una fuente de carbono diferente de los de la lista está en el medio mínimo, lo eliminaremos también.

# %%
#Lista con las fuentes de carbono permitidas
fuentes_C = ["glucose", "rhamnose", "xylose", "glucuronic", "furfural", "hydroxymethylfurfural"]

#Para cada una de las reacciones de exchange evaluamos sus metabolitos
#Si alguno contiene C, añadimos la reacción a una lista, excepto si es alguno de las fuentes permitidas
#Tampoco lo añadimos si pertenece al medio mínimo
#Para todas las reacciones de esa lista se setearán los bound a 0 en el medio
#Es decir, eliminamos los exchange al menos que sean del medio mínimo o sean de alguno de los azúcares permitidos

#La siguiente función implementa lo anterior
#Además, devuelve la lista de exchanges a eliminar y de exchanges de fuentes de carbono admitidos
def update_media(model, fuentes_C = fuentes_C):
    exchange_elim = []
    #Obtenemos la lista de objetos metabolito del modelo asociados a fuentes de carbono permitidas o metabolitos del medio mínimo
    admitted_mets = []
    for admitted in fuentes_C:
        #Nos quedamos con los objetos metabolitos asociados a esa fuente
        for met in model.metabolites:
            if admitted in met.name.lower():
                admitted_mets.append(met)
    #Añadimos los objetos metabolito del medio mínimo, a menos que sean azúcares diferentes de los permitidos
    minimal = minimal_medium(model).index #Lista de identificadores de exchanges del medio mínimo
    for iden in minimal:
        rx = model.reactions.get_by_id(iden)
        metab = list(rx.metabolites.keys())[0]
        if not ("ose" in metab.name.lower() and not any(azucar in metab.name.lower() for azucar in fuentes_C)):
            admitted_mets.append(metab)
    
    #Para cada reacción de exchange que implique carbono decidimos si la mantenemos o no
    for ex in model.medium.keys():
        rx = model.reactions.get_by_id(ex) 
        no_elim = False
        #Comprobamos si es una fuente de carbono permitida o del medio mínimo
        if admitted_mets:
            met = list(rx.metabolites.keys())[0]
            for admit in admitted_mets:
                if met.id == admit.id: #Para que las nomenclaturas coincidan
                    no_elim = True

        #Se elimina la reacción si el metabolito no está admitido
        if no_elim == False:
            exchange_elim.append(ex)

    #Seteamos los bounds a 0 de las reacciones seleccionadas para eliminar las fuentes de carbono
    media = model.medium
    for rx in exchange_elim:
        media[rx] = 0
    model.medium = media
    
    #Nos quedamos con los nombres de los metabolitos del medio actualizado
    medio_final = []
    for iden in model.medium.keys():
        rx = model.reactions.get_by_id(iden)
        met = list(rx.metabolites)[0]
        medio_final.append(met.name)

    return medio_final, exchange_elim, admitted_mets

# %% [markdown]
# ### Análisis final

# %% [markdown]
# Para cada uno de los organismos soportados en AGORA2 hacemos el análisis. Nos quedamos con un diccionario con los nombres de las especies y una tupla que contiene:
# - Valor máximo de crecimiento (si solo hay una cepa que crece, este será el valor máximo)
# - Cepas que crecen, con su valor de crecimiento y composición del medio
#
# Creamos una función que realiza el análisis a partir de una lista de especies:

# %%
def growth_analysis(lista, fuentes_C = fuentes_C):
    resultado = {}
    modelos_error = []
    for especie, modelos in lista.items():
        crec_max = 0
        cepas_crec = {}
        #Recorremos todos los modelos de la especie y obtenemos el crecimiento máximo y las cepas que crecen
        #Para cada cepa que crece guardamos también los componentes del medio
        for nombre_modelo in modelos:
            try:
                model = descargar_agora2(nombre_modelo)
                medio_final = update_media(model)
                crec = model.slim_optimize()
                if crec != 0:
                    print(str(int(crec)),";", end="") #Estado
                    cepas_crec[nombre_modelo] = [crec, medio_final[0]] #Guardamos la cepa, su valor de crecimiento y el medio que necesita
                    if crec > crec_max:
                        crec_max = crec
                else:
                    print(".", end="") #Estado
            except:
                modelos_error.append(nombre_modelo)
                
        #Si alguna de las cepas crece, guardamos el resultado
        if crec_max != 0:
            tupla = (crec_max, cepas_crec)
            resultado[especie] = tupla
        #Estado del análisis
        print("\n", especie, " analizada")

    return resultado

# %% [markdown]
# # Análisis de organismos con modelo en AGORA2

# %%
#Importamos del excel y creamos las 3 listas
excel_path = "QPS_Lista_Danesa_List_June_2023_mod.xlsx"
especies_modelos = leer_excel(excel_path)[0]
generos_modelos = leer_excel(excel_path)[1]
no_modelos = leer_excel(excel_path)[2]

# %% [markdown]
# Realizamos el análisis descrito para la lista de especies que tienen algún modelo en AGORA2:

# %%
warnings.filterwarnings('ignore')
resultado = growth_analysis(especies_modelos)
resultado
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-02-12
# 86 ;83 ;47 ;42 ;47 ;
#  Hafnia_alvei  analizada
# 41 ;
#  Bifidobacterium_pseudolongum  analizada
# 55 ;
#  Bifidobacterium_thermophilum  analizada
# 26 ;23 ;27 ;24 ;24 ;23 ;24 ;34 ;24 ;25 ;24 ;24 ;30 ;
#  Bifidobacterium_adolescentis  analizada
# 38 ;37 ;40 ;30 ;35 ;34 ;43 ;36 ;43 ;33 ;29 ;32 ;40 ;27 ;27 ;27 ;27 ;
#  Bifidobacterium_animalis  analizada
# 30 ;27 ;29 ;30 ;31 ;26 ;29 ;29 ;
#  Bifidobacterium_bifidum  analizada
# 27 ;27 ;27 ;36 ;30 ;36 ;35 ;40 ;31 ;27 ;27 ;27 ;28 ;27 ;28 ;28 ;28 ;27 ;27 ;27 ;27 ;28 ;25 ;
#  Bifidobacterium_breve  analizada
# 34 ;40 ;53 ;41 ;41 ;41 ;41 ;41 ;41 ;41 ;34 ;28 ;33 ;34 ;24 ;39 ;35 ;34 ;34 ;
#  Bifidobacterium_longum  analizada
# .
#  Brevibacterium_linens  analizada
# 62 ;
#  Brevibacterium_casei  analizada
# 45 ;
#  Corynebacterium_ammoniagenes  analizada
# 18 ;18 ;
#  Corynebacterium_casei  analizada
# 27 ;.43 ;
#  Lactobacillus_acidophilus  analizada
# 17 ;
#  Lactobacillus_amylolyticus  analizada
# 41 ;40 ;36 ;
#  Lactobacillus_amylovorus  analizada
# 34 ;11 ;45 ;32 ;32 ;44 ;44 ;44 ;47 ;
#  Lactobacillus_crispatus  analizada
# 29 ;38 ;37 ;17 ;32 ;34 ;35 ;18 ;32 ;
#  Lactobacillus_delbrueckii  analizada
# 54 ;24 ;42 ;55 ;39 ;39 ;42 ;42 ;39 ;54 ;54 ;
#  Lactobacillus_gasseri  analizada
# 46 ;27 ;29 ;41 ;
#  Lactobacillus_helveticus  analizada
# 36 ;39 ;41 ;41 ;39 ;42 ;41 ;
#  Lactobacillus_johnsonii  analizada
# 40 ;
#  Lactobacillus_kefiranofaciens  analizada
# 23 ;26 ;20 ;20 ;39 ;20 ;25 ;26 ;30 ;26 ;26 ;
#  Lactococcus_lactis  analizada
# 49 ;50 ;46 ;60 ;53 ;
#  Leuconostoc_citreum  analizada
# 27 ;
#  Leuconostoc_lactis  analizada
# 47 ;46 ;49 ;64 ;
#  Leuconostoc_mesenteroides  analizada
# 22 ;56 ;
#  Leuconostoc_pseudomesenteroides  analizada
# 44 ;
#  Microbacterium_gubbeenense  analizada
# 34 ;34 ;47 ;49 ;47 ;49 ;49 ;38 ;48 ;43 ;43 ;43 ;24 ;
#  Pediococcus_acidilactici  analizada
# 27 ;23 ;
#  Pediococcus_pentosaceus  analizada
# .
#  Propionibacterium_acidipropionici  analizada
# 57 ;59 ;
#  Propionibacterium_freudenreichii  analizada
# 35 ;34 ;46 ;29 ;36 ;36 ;32 ;36 ;33 ;31 ;36 ;35 ;29 ;33 ;32 ;33 ;31 ;33 ;32 ;33 ;33 ;32 ;33 ;45 ;92 ;45 ;45 ;45 ;45 ;87 ;44 ;45 ;32 ;33 ;33 ;35 ;33 ;33 ;33 ;33 ;33 ;33 ;33 ;33 ;33 ;33 ;33 ;33 ;32 ;33 ;33 ;29 ;33 ;33 ;33 ;33 ;33 ;33 ;32 ;33 ;33 ;32 ;33 ;33 ;33 ;33 ;33 ;33 ;33 ;32 ;33 ;33 ;33 ;33 ;33 ;33 ;32 ;32 ;33 ;33 ;33 ;33 ;33 ;32 ;32 ;33 ;32 ;33 ;33 ;33 ;33 ;33 ;33 ;33 ;33 ;33 ;32 ;32 ;33 ;32 ;32 ;33 ;32 ;32 ;36 ;32 ;32 ;33 ;33 ;79 ;32 ;29 ;35 ;32 ;33 ;33 ;32 ;45 ;45 ;33 ;44 ;34 ;35 ;32 ;33 ;35 ;33 ;71 ;71 ;71 ;71 ;71 ;71 ;71 ;71 ;71 ;71 ;Error_modelo
# 71 ;71 ;71 ;71 ;71 ;71 ;71 ;71 ;71 ;71 ;71 ;35 ;35 ;35 ;35 ;35 ;34 ;35 ;35 ;35 ;35 ;35 ;34 ;35 ;35 ;35 ;34 ;36 ;36 ;35 ;33 ;31 ;30 ;35 ;35 ;71 ;34 ;35 ;32 ;35 ;36 ;32 ;33 ;32 ;55 ;34 ;36 ;33 ;35 ;34 ;33 ;33 ;32 ;33 ;31 ;32 ;45 ;32 ;32 ;32 ;33 ;36 ;33 ;32 ;35 ;36 ;36 ;35 ;32 ;32 ;36 ;36 ;35 ;32 ;36 ;35 ;34 ;47 ;32 ;33 ;31 ;32 ;34 ;32 ;32 ;35 ;32 ;32 ;33 ;33 ;32 ;32 ;33 ;33 ;31 ;32 ;33 ;45 ;32 ;35 ;35 ;34 ;35 ;35 ;58 ;35 ;35 ;35 ;35 ;35 ;35 ;35 ;32 ;35 ;34 ;35 ;33 ;54 ;42 ;35 ;33 ;35 ;54 ;35 ;35 ;35 ;35 ;35 ;36 ;36 ;35 ;36 ;36 ;36 ;36 ;36 ;36 ;36 ;35 ;36 ;36 ;36 ;54 ;35 ;32 ;33 ;34 ;31 ;45 ;
#  Enterococcus_faecalis  analizada
# 33 ;33 ;34 ;33 ;23 ;34 ;34 ;34 ;30 ;33 ;30 ;33 ;33 ;33 ;33 ;33 ;32 ;32 ;33 ;33 ;33 ;32 ;32 ;33 ;33 ;33 ;33 ;34 ;30 ;32 ;30 ;29 ;33 ;35 ;34 ;34 ;29 ;33 ;32 ;32 ;29 ;33 ;33 ;32 ;33 ;30 ;36 ;33 ;33 ;32 ;29 ;30 ;32 ;29 ;33 ;33 ;29 ;32 ;33 ;33 ;33 ;33 ;33 ;29 ;32 ;32 ;33 ;34 ;33 ;33 ;33 ;33 ;23 ;34 ;29 ;34 ;36 ;34 ;32 ;32 ;32 ;33 ;29 ;29 ;29 ;23 ;33 ;29 ;29 ;32 ;29 ;33 ;29 ;43 ;46 ;46 ;43 ;43 ;30 ;32 ;33 ;30 ;30 ;30 ;30 ;30 ;30 ;30 ;30 ;30 ;30 ;29 ;32 ;33 ;32 ;33 ;33 ;32 ;32 ;33 ;29 ;34 ;33 ;34 ;34 ;35 ;35 ;34 ;34 ;33 ;34 ;30 ;30 ;30 ;30 ;30 ;37 ;30 ;32 ;34 ;33 ;33 ;33 ;33 ;33 ;33 ;33 ;29 ;32 ;32 ;33 ;33 ;29 ;29 ;29 ;33 ;29 ;29 ;29 ;33 ;29 ;29 ;29 ;29 ;34 ;29 ;33 ;33 ;33 ;29 ;34 ;34 ;29 ;27 ;33 ;33 ;33 ;33 ;33 ;32 ;33 ;33 ;29 ;33 ;
#  Enterococcus_faecium  analizada
# 21 ;21 ;21 ;20 ;21 ;21 ;
#  Streptococcus_thermophilus  analizada
# 29 ;22 ;23 ;23 ;23 ;25 ;30 ;
#  Bacillus_amyloliquefaciens  analizada
# 27 ;69 ;27 ;58 ;27 ;.27 ;27 ;27 ;27 ;35 ;27 ;27 ;27 ;37 ;.
#  Bacillus_atrophaeus  analizada
# 60 ;44 ;60 ;60 ;60 ;60 ;
#  Bacillus_licheniformis  analizada
# 32 ;
#  Bacillus_mojavensis  analizada
# .
#  Bacillus_paralicheniformis  analizada
# 27 ;26 ;66 ;
#  Bacillus_pumilus  analizada
# 40 ;
#  Bacillus_smithii  analizada
# 40 ;50 ;38 ;43 ;39 ;25 ;26 ;25 ;40 ;26 ;40 ;40 ;40 ;37 ;25 ;25 ;40 ;25 ;
#  Bacillus_subtilis  analizada
# 28 ;
#  Bacillus_vallismortis  analizada
# 30 ;30 ;30 ;
#  Bacillus_velezensis  analizada
# 33 ;
#  Geobacillus_stearothermophilus  analizada
# 25 ;
#  Lysinibacillus_fusiformis  analizada
# {'Hafnia_alvei': (86.23460964184649,
#   {'Hafnia_alvei_ATCC_51873.xml': [86.23460964184649,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosine',
#      'L-alanyl-L-histidine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Cytidine',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycyl-L-methionine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 8',
#      'NMN',
#      'O2',
#      'octadecanoate (n-C18:0)',
#      'Ornithine',
#      'L-Rhamnose',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'thiosulfate(2-)',
#      'tetradecanoate (n-C14:0)',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Hafnia_alvei_BIDMC_31.xml': [83.09600043600281,
#     ['Adenosine',
#      'L-alanyl-L-histidine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Cytidine',
#      'Fe3+',
#      'D-Glucose 6-phosphate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-methionine',
#      'Guanosine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'NMN',
#      'O2',
#      'Riboflavin',
#      'L-Rhamnose',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Hafnia_alvei_ERR2221402.xml': [47.44633397020385,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'cytosine',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycylleucine',
#      'Glycylphenylalanine',
#      'Glycyl-L-tyrosine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 8',
#      'NMN',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'L-Rhamnose',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'tetradecanoate (n-C14:0)',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Hafnia_alvei_FB1.xml': [42.42319389780953,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosine',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-arginine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'laurate',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Gly-Cys',
#      'Glycyl-L-glutamine',
#      'Glycylphenylalanine',
#      'Glycyl-L-tyrosine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 8',
#      'NMN',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      'L-Rhamnose',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'tetradecanoate (n-C14:0)',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Hafnia_alvei_HUMV_5920.xml': [47.442286930309436,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'cytosine',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycylleucine',
#      'Glycylphenylalanine',
#      'Glycyl-L-tyrosine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 8',
#      'NMN',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'L-Rhamnose',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'tetradecanoate (n-C14:0)',
#      'aldehydo-D-xylose',
#      'Zinc']]}),
#  'Bifidobacterium_pseudolongum': (41.748870935399424,
#   {'Bifidobacterium_pseudolongum_subsp_Pseudolongum_DSM_20099.xml': [41.748870935399424,
#     ['Adenine',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'L-asparagine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'L-cysteine',
#      'Fe2+',
#      'Folate',
#      'D-Glucosamine',
#      'D-glucose',
#      'Glycyl-L-glutamine',
#      'Guanine',
#      'L-histidine',
#      'potassium',
#      'L-lysine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Ornithine',
#      'Orotate',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)',
#      'Riboflavin',
#      'sulfate',
#      'Thiamin',
#      'L-threonine',
#      'L-tryptophan',
#      'L-tyrosine',
#      'aldehydo-D-xylose',
#      'Zinc']]}),
#  'Bifidobacterium_thermophilum': (55.93248115621994,
#   {'Bifidobacterium_thermophilum_RBL67.xml': [55.93248115621994,
#     ['Adenine',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'L-arginine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'Guanine',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'O2',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Urea',
#      'Zinc']]}),
#  'Bifidobacterium_adolescentis': (34.8098976691214,
#   {'Bifidobacterium_adolescentis_ATCC_15703.xml': [26.019065948674193,
#     ['4-Aminobenzoate',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 8',
#      'Nicotinate',
#      'octadecanoate (n-C18:0)',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'Siroheme',
#      'sulfate',
#      'Thiamin',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_BBMN23.xml': [23.462445764629372,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_DSM_20087.xml': [27.543796497543973,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenine',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Glycyl-L-tyrosine',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Orotate',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Resistant starch',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_ERR1022283.xml': [24.164256366956568,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Glycyl-L-tyrosine',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_ERR1022320.xml': [24.166073009821677,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Glycyl-L-tyrosine',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_ERR1022366.xml': [23.959921417961073,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Glycyl-L-tyrosine',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_ERR1203960.xml': [24.16606983954134,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Glycyl-L-tyrosine',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_ERR2221193.xml': [34.8098976691214,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Glycyl-L-tyrosine',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Resistant starch',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_ERR2221322.xml': [24.16504171145108,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Glycyl-L-tyrosine',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_ERR2230053.xml': [25.74085385817395,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'L-arginine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Glycyl-L-tyrosine',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_ERR2230077.xml': [24.16424502239979,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Glycyl-L-tyrosine',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_ERR2230153.xml': [24.164253614232283,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Glycyl-L-tyrosine',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_adolescentis_L2_32.xml': [30.702585378651595,
#     ['4-Aminobenzoate',
#      'Adenine',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'Guanine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Resistant starch',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']]}),
#  'Bifidobacterium_animalis': (43.782633431434995,
#   {'Bifidobacterium_animalis_ERR2221337.xml': [38.04443432577477,
#     ['meso-2,6-Diaminoheptanedioate',
#      'L-arginine',
#      'L-asparagine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Dextrin',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Gly-Cys',
#      'Glycylleucine',
#      'L-histidine',
#      'Hypoxanthine',
#      'potassium',
#      'L-leucine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'octadecanoate (n-C18:0)',
#      'L-phenylalanine',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'L-tyrosine',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_ERR2221385.xml': [37.69292087349585,
#     ['meso-2,6-Diaminoheptanedioate',
#      'L-arginine',
#      'L-asparagine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Gly-Cys',
#      'Glycylleucine',
#      'L-histidine',
#      'Hypoxanthine',
#      'potassium',
#      'L-leucine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'octadecanoate (n-C18:0)',
#      'L-phenylalanine',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'L-tyrosine',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_RH.xml': [40.55284850004535,
#     ['Adenine',
#      'L-arginine',
#      'L-asparagine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'L-cysteine',
#      'Dextrin',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Guanine',
#      'L-histidine',
#      'potassium',
#      'L-lysine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-threonine',
#      'uracil',
#      'Urea',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_lactis_AD011.xml': [30.701667036030265,
#     ['L-arginine',
#      'L-asparagine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Dephospho-CoA',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Gly-Cys',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'L-histidine',
#      'Hypoxanthine',
#      'potassium',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'hydrogenphosphate',
#      'Riboflavin',
#      'sulfate',
#      'uracil',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_lactis_BB_12.xml': [35.18881215756939,
#     ['L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Dextrin',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'Glycyl-L-glutamine',
#      'Glycyl-L-methionine',
#      'L-histidine',
#      'Hypoxanthine',
#      'potassium',
#      'L-lysine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'octadecanoate (n-C18:0)',
#      'Ornithine',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_lactis_Bi_07.xml': [34.482514278386134,
#     ['L-arginine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Dextrin',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'Glycyl-L-glutamine',
#      'Glycyl-L-methionine',
#      'L-histidine',
#      'Hypoxanthine',
#      'potassium',
#      'L-lysine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'octadecanoate (n-C18:0)',
#      'Ornithine',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Thiamin',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_lactis_Bl_04_ATCC_SD5219.xml': [43.782633431434974,
#     ['L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycyl-L-methionine',
#      'Hypoxanthine',
#      'potassium',
#      'L-lysine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'O2',
#      'octadecanoate (n-C18:0)',
#      'Ornithine',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_lactis_CNCM_I_2494.xml': [36.37619955101169,
#     ['meso-2,6-Diaminoheptanedioate',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'L-asparagine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Gly-Cys',
#      'Glycylleucine',
#      'L-histidine',
#      'Hypoxanthine',
#      'potassium',
#      'L-leucine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 8',
#      'Nicotinate',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'L-proline',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'uracil',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_lactis_DSM_10140.xml': [43.782633431434995,
#     ['L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycyl-L-methionine',
#      'Hypoxanthine',
#      'potassium',
#      'L-lysine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'O2',
#      'octadecanoate (n-C18:0)',
#      'Ornithine',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_lactis_V9.xml': [33.27611021177668,
#     ['L-arginine',
#      'L-asparagine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycylleucine',
#      'L-histidine',
#      'Hypoxanthine',
#      'potassium',
#      'L-leucine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_subsp_animalis_ATCC_25527.xml': [29.211977490776842,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'L-alanyl-L-aspartate',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-alanyl-L-threonine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Dextrin',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'Glycyl-L-tyrosine',
#      'Hypoxanthine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_subsp_animalis_ATCC_27672.xml': [32.86968635676255,
#     ['meso-2,6-Diaminoheptanedioate',
#      'L-asparagine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Dextrin',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycylleucine',
#      'L-histidine',
#      'Hypoxanthine',
#      'potassium',
#      'L-leucine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'octadecanoate (n-C18:0)',
#      'L-phenylalanine',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'L-tyrosine',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_subsp_animalis_YL2.xml': [40.150244101978075,
#     ['Adenine',
#      'L-arginine',
#      'L-asparagine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'L-cysteine',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'Guanine',
#      'L-histidine',
#      'potassium',
#      'L-lysine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-threonine',
#      'uracil',
#      'Urea',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_subsp_lactis_B420.xml': [27.680324732969954,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-alanyl-L-threonine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Dextrin',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'Glycyl-L-tyrosine',
#      'Hypoxanthine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-serine',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_subsp_lactis_BLC1.xml': [27.45339402613588,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'L-alanyl-L-aspartate',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Dextrin',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'Glycyl-L-tyrosine',
#      'Hypoxanthine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-serine',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'uracil',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_subsp_lactis_BS_01.xml': [27.45339402613588,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'L-alanyl-L-aspartate',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Dextrin',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'Glycyl-L-tyrosine',
#      'Hypoxanthine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-serine',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'uracil',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_animalis_subsp_lactis_HN019.xml': [27.525228753425456,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-alanyl-L-threonine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-tyrosine',
#      'Hypoxanthine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-serine',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']]}),
#  'Bifidobacterium_bifidum': (31.57824128887476,
#   {'Bifidobacterium_bifidum_156B.xml': [30.11661359837004,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'Larch arabinogalactan',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycylleucine',
#      'Glycyl-L-tyrosine',
#      'GlcNAc-alpha-1,4-Core 2',
#      'Guanine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_bifidum_ATCC_29521.xml': [27.43313040533571,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'Larch arabinogalactan',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycylleucine',
#      'Glycyl-L-tyrosine',
#      'GlcNAc-alpha-1,4-Core 2',
#      'Guanine',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_bifidum_BGN4.xml': [29.951643969360784,
#     ['L-alanyl-L-histidine',
#      'Larch arabinogalactan',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'Glycyl-L-methionine',
#      'GlcNAc-alpha-1,4-Core 2',
#      'Hypoxanthine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_bifidum_ERR1022335.xml': [30.116625843015626,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'Larch arabinogalactan',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycylleucine',
#      'Glycyl-L-tyrosine',
#      'GlcNAc-alpha-1,4-Core 2',
#      'Guanine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_bifidum_LMG_13195.xml': [31.57824128887476,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'Adenosine',
#      'L-alanyl-L-histidine',
#      'Larch arabinogalactan',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-methionine',
#      'GlcNAc-alpha-1,4-Core 2',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Menaquinone 8',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Pyridoxal 5-phosphate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_bifidum_NCIMB_41171.xml': [26.617685662149675,
#     ['meso-2,6-Diaminoheptanedioate',
#      'L-alanyl-L-histidine',
#      'Larch arabinogalactan',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Dephospho-CoA',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-methionine',
#      'GlcNAc-alpha-1,4-Core 2',
#      'Hypoxanthine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'hydrogenphosphate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_bifidum_PRL2010.xml': [29.872858119223466,
#     ['Adenine',
#      'L-alanyl-L-histidine',
#      'Larch arabinogalactan',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-methionine',
#      'GlcNAc-alpha-1,4-Core 2',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'Siroheme',
#      'sulfate',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_bifidum_S17.xml': [29.89725859404358,
#     ['L-alanyl-L-histidine',
#      'Larch arabinogalactan',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'Glycyl-L-methionine',
#      'GlcNAc-alpha-1,4-Core 2',
#      'Hypoxanthine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'L-Rhamnose',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']]}),
#  'Bifidobacterium_breve': (40.90547603424815,
#   {'Bifidobacterium_breve_2L.xml': [27.34561038960459,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'Amylopectin, 900 repeat units',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'L-cysteine',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'L-histidine',
#      'potassium',
#      'L-leucine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Orotate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'L-tyrosine',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_12L.xml': [27.43853050898143,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'Amylopectin, 900 repeat units',
#      'L-arginine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'L-cysteine',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'L-histidine',
#      'potassium',
#      'L-leucine',
#      'L-lysine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Orotate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'L-tyrosine',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_689b.xml': [27.725883285743777,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'Amylopectin, 900 repeat units',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycyl-L-glutamine',
#      'L-histidine',
#      'potassium',
#      'L-leucine',
#      'L-lysine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Orotate',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'L-tyrosine',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_ACS_071_V_Sch8b.xml': [36.68310155959075,
#     ['4-Aminobenzoate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'Amylopectin, 900 repeat units',
#      'L-arginine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Gly-Cys',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_CECT_7263.xml': [30.55496278899452,
#     ['4-Aminobenzoate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'Amylopectin, 900 repeat units',
#      'L-arginine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Gly-Cys',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_DPC_6330.xml': [36.305208765182165,
#     ['4-Aminobenzoate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'Amylopectin, 900 repeat units',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_DSM_20213.xml': [35.5422397510897,
#     ['4-Aminobenzoate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'Amylopectin, 900 repeat units',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Gly-Cys',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_ERR2230051.xml': [40.90547603424815,
#     ['Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'Amylopectin, 900 repeat units',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'cytosine',
#      'Cu2+',
#      'L-cysteine',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycylleucine',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'L-tyrosine',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_HPH0326.xml': [31.36455351842565,
#     ['4-Aminobenzoate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'Amylopectin, 900 repeat units',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'Glycyl-L-methionine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 7',
#      'Nicotinate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_JCM_7017.xml': [27.74058856356094,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'Amylopectin, 900 repeat units',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycylleucine',
#      'L-histidine',
#      'potassium',
#      'L-leucine',
#      'L-lysine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Orotate',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'L-tyrosine',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_JCM_7019.xml': [27.439396861364255,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'Amylopectin, 900 repeat units',
#      'L-arginine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'L-cysteine',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycyl-L-glutamine',
#      'L-histidine',
#      'potassium',
#      'L-leucine',
#      'L-lysine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Orotate',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'L-tyrosine',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_MCC_0121.xml': [27.63777660048493,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'Amylopectin, 900 repeat units',
#      'L-arginine',
#      'calcium(2+)',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'L-cysteine',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycyl-L-glutamine',
#      'L-histidine',
#      'potassium',
#      'L-leucine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Orotate',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'L-tyrosine',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bifidobacterium_breve_MCC_0305.xml': [28.454882087239067,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-glutamine',
#      'L-alanyl-L-histidine',
#      'Amylopectin, 900 repeat units',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'L-cysteine',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycyl-L-tyrosine',
#      'potassium',
#      'L-leucine',
#      'L-Methionine Sulfoxide',
#      'magnesium',
#      'Mn2+',
#      'Orotate',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'Riboflavin',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'L-tyrosine',
#      'Urea',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
# ...
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Guanine',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_B_1.xml': [50.487196311065595,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-histidine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'octadecanoate (n-C18:0)',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_ERR2221132.xml': [38.96211594307711,
#     ['meso-2,6-Diaminoheptanedioate',
#      'Adenosine',
#      'Adenosylcobalamin',
#      'L-alanyl-L-histidine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycylleucine',
#      'Glycyl-L-methionine',
#      'potassium',
#      'L-lysine',
#      'magnesium',
#      'Mn2+',
#      'octadecanoate (n-C18:0)',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_QB928.xml': [43.19903631815297,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-histidine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Gly-Cys',
#      'Glycylleucine',
#      'Guanine',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_str_168.xml': [39.244843533361255,
#     ['meso-2,6-Diaminoheptanedioate',
#      '4-hydroxybenzoate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-histidine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycerol 3-phosphate',
#      'glycogen, structure 2 (glycogenin-1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#      'Glycyl-L-methionine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'O2',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      'sulfate',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_natto_BEST195.xml': [25.772475787960996,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'cytosine',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'pectins',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'sulfate',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_spizizenii_ATCC_6633.xml': [26.19802955807227,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'cytosine',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Gly-Cys',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'pectins',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'sulfate',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_spizizenii_DV1_B_1.xml': [25.881184345222493,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'cytosine',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'pectins',
#      'Protoheme',
#      'hydrogenphosphate',
#      '(R)-Pantothenate',
#      'sulfate',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_spizizenii_TU_B_10.xml': [40.23064167153773,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'meso-2,6-Diaminoheptanedioate',
#      'N-acetyl-D-glucosamine',
#      'Adenosylcobalamin',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Guanine',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_spizizenii_str_W23.xml': [26.198030590601523,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'cytosine',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'pectins',
#      'Protoheme',
#      '(R)-Pantothenate',
#      'sulfate',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_subtilis_516_BAMY_102_633920_16710904.xml': [40.18764082928058,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Gly-Cys',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_subtilis_6051_HGW.xml': [40.22240776035749,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Guanine',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_subtilis_str_BAB_1.xml': [40.22236112688928,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Gly-Cys',
#      'Guanine',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_subtilis_str_BSP1.xml': [37.2337785321079,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-histidine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycylleucine',
#      'Guanine',
#      'L-isoleucine',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_subtilis_str_JH642.xml': [25.050228269703425,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      '4-hydroxybenzoate',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'cytosine',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_subtilis_str_NCIB_3610.xml': [25.05046765986805,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'cytosine',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_subtilis_str_RO_NN_1.xml': [40.30394785795901,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'meso-2,6-Diaminoheptanedioate',
#      'Adenosylcobalamin',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Gly-Cys',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_subtilis_subsp_subtilis_str_SMY.xml': [25.051218708494904,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      '4-hydroxybenzoate',
#      'L-alanyl-L-threonine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'cytosine',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'potassium',
#      'L-lysine',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'Nicotinate',
#      'pectins',
#      'Protoheme',
#      'sulfate',
#      'aldehydo-D-xylose',
#      'Zinc']]}),
#  'Bacillus_vallismortis': (28.765618643102016,
#   {'Bacillus_vallismortis_DV1_F_3.xml': [28.765618643102016,
#     ['meso-2,6-Diaminoheptanedioate',
#      '2-Demethylmenaquinone 8',
#      'N-acetyl-D-glucosamine',
#      'Adenosine',
#      'L-alanyl-L-histidine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Cytidine',
#      'Deoxyguanosine',
#      'Fe3+',
#      'Folate',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Guanine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 8',
#      'O2',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      'Ubiquinone-8',
#      'Riboflavin',
#      'L-Rhamnose',
#      'Siroheme',
#      'sulfate',
#      'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#      'Thiamin',
#      'aldehydo-D-xylose',
#      'Zinc']]}),
#  'Bacillus_velezensis': (30.710294146829636,
#   {'Bacillus_velezensis_AS433.xml': [30.710294146829636,
#     ['meso-2,6-Diaminoheptanedioate',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycylleucine',
#      'Hypoxanthine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      'Riboflavin',
#      'sulfate',
#      'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#      'Thiamin',
#      'thiosulfate(2-)',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_velezensis_L_H15.xml': [30.71029040686285,
#     ['meso-2,6-Diaminoheptanedioate',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycylleucine',
#      'Hypoxanthine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      'Riboflavin',
#      'sulfate',
#      'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#      'Thiamin',
#      'thiosulfate(2-)',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']],
#    'Bacillus_velezensis_UCMB5036.xml': [30.710293496400556,
#     ['meso-2,6-Diaminoheptanedioate',
#      'L-alanyl-L-histidine',
#      'L-alanyl-L-leucine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Glycylleucine',
#      'Hypoxanthine',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      'Riboflavin',
#      'sulfate',
#      'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#      'Thiamin',
#      'thiosulfate(2-)',
#      'Xanthine',
#      'aldehydo-D-xylose',
#      'Zinc']]}),
#  'Geobacillus_stearothermophilus': (33.72374954935539,
#   {'Geobacillus_stearothermophilus_ATCC_7953.xml': [33.72374954935539,
#     ['meso-2,6-Diaminoheptanedioate',
#      '4-hydroxybenzoate',
#      'L-alanyl-L-histidine',
#      'L-arginine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe3+',
#      'D-glucose',
#      'Glycyl-L-asparagine',
#      'Glycerol 3-phosphate',
#      'Gly-Cys',
#      'Guanine',
#      'Hypoxanthine',
#      'Chicory inulin',
#      'potassium',
#      'L-methionyl-L-alanine',
#      'magnesium',
#      'Mn2+',
#      'O2',
#      'octadecanoate (n-C18:0)',
#      'Protoheme',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'uracil',
#      'Zinc']]}),
#  'Lysinibacillus_fusiformis': (25.520363850241523,
#   {'Lysinibacillus_fusiformis_ZB2.xml': [25.520363850241523,
#     ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#      'meso-2,6-Diaminoheptanedioate',
#      '4-hydroxybenzoate',
#      'N-acetyl-D-glucosamine',
#      'L-alanyl-L-leucine',
#      'calcium(2+)',
#      'L-cysteinylglycine',
#      'Chloride',
#      'Co2+',
#      'Cu2+',
#      'Fe3+',
#      'D-Glucosamine',
#      'D-glucose',
#      'Glycyl-L-tyrosine',
#      'Inosine',
#      'potassium',
#      'magnesium',
#      'Mn2+',
#      'Menaquinone 8',
#      'O2',
#      'Protoheme',
#      'hydrogenphosphate',
#      'Pyridoxal',
#      'Riboflavin',
#      'Siroheme',
#      'sulfate',
#      'Spermidine',
#      'Thiamin',
#      'L-tryptophan',
#      'thiosulfate(2-)',
#      'Uridine',
#      'Zinc']]})}

# %%
#Exportamos el resultado a json
with open('Initial_approach_minimal_result.json', 'w') as archivo:
    json.dump(resultado, archivo)

# %% [markdown]
# ## Análisis de los resultados

# %%
#Importamos los resultados
with open('Initial_approach_minimal_result.json', 'r') as archivo:
    resultados = json.load(archivo)

# %% [markdown]
# Ordenamos los modelos de las especies que crecen de mejor a peor en función de la cantidad de metabolitos que forman parte del medio (cuanto menor número, mejor). En caso de empate, el mejor modelo será aquel con mayor crecimiento. Guardamos para cada especie un diccionario con el nombre del mejor modelo, la composición del medio necesario, el número de metabolitos del medio y su crecimiento predicho.

# %%
mejor_modelo = {}
for especie, info in resultados.items():
    info_mejor = {} #Diccionario con información del mejor modelo
    mejor = None
    tamaño_medio = 1000
    dicc_modelos = info[1]
    for mod, crec_medio in dicc_modelos.items():
        medio = crec_medio[1]
        if len(medio) < tamaño_medio:
            mejor = mod
        elif len(medio) == tamaño_medio:
                crec_mejor = dicc_modelos[mejor][0]
                crec_candidato = crec_medio[0]
                if crec_candidato > crec_mejor:
                    mejor = mod
    #Guardamos para cada especie un diccionario con información sobre el mejor modelo
    info_mejor["Nombre"] = mejor
    info_mejor["Medio"] = dicc_modelos[mejor][1]
    info_mejor["Tamaño_medio"] = len(dicc_modelos[mejor][1])
    info_mejor["Crecimiento"] = dicc_modelos[mejor][0]
    mejor_modelo[especie] = info_mejor

# %%
mejor_modelo
# Out:
# {'Hafnia_alvei': {'Nombre': 'Hafnia_alvei_HUMV_5920.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-Rhamnose',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'tetradecanoate (n-C14:0)',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 37,
#   'Crecimiento': 47.442286930309436},
#  'Bifidobacterium_pseudolongum': {'Nombre': 'Bifidobacterium_pseudolongum_subsp_Pseudolongum_DSM_20099.xml',
#   'Medio': ['Adenine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-asparagine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe2+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-glutamine',
#    'Guanine',
#    'L-histidine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Ornithine',
#    'Orotate',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)',
#    'Riboflavin',
#    'sulfate',
#    'Thiamin',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 36,
#   'Crecimiento': 41.748870935399424},
#  'Bifidobacterium_thermophilum': {'Nombre': 'Bifidobacterium_thermophilum_RBL67.xml',
#   'Medio': ['Adenine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Guanine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Urea',
#    'Zinc'],
#   'Tamaño_medio': 29,
#   'Crecimiento': 55.93248115621994},
#  'Bifidobacterium_adolescentis': {'Nombre': 'Bifidobacterium_adolescentis_L2_32.xml',
#   'Medio': ['4-Aminobenzoate',
#    'Adenine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Guanine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Spermidine',
#    'Resistant starch',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 30,
#   'Crecimiento': 30.702585378651595},
#  'Bifidobacterium_animalis': {'Nombre': 'Bifidobacterium_animalis_subsp_lactis_HN019.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 35,
#   'Crecimiento': 27.525228753425456},
#  'Bifidobacterium_bifidum': {'Nombre': 'Bifidobacterium_bifidum_S17.xml',
#   'Medio': ['L-alanyl-L-histidine',
#    'Larch arabinogalactan',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycyl-L-methionine',
#    'GlcNAc-alpha-1,4-Core 2',
#    'Hypoxanthine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 29.89725859404358},
#  'Bifidobacterium_breve': {'Nombre': 'Bifidobacterium_breve_UCC2003_NCIMB8807.xml',
#   'Medio': ['Adenosylcobalamin',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'Amylopectin, 900 repeat units',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycyl-L-methionine',
#    'Glycylproline',
#    'Hypoxanthine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 33,
#   'Crecimiento': 25.374629475378395},
#  'Bifidobacterium_longum': {'Nombre': 'Bifidobacterium_longum_subsp_longum_NCIMB8809.xml',
#   'Medio': ['Adenosylcobalamin',
#    'L-alanyl-L-histidine',
#    'Larch arabinogalactan',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Protoheme',
#    'hydrogenphosphate',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 28,
#   'Crecimiento': 34.414649951689135},
#  'Brevibacterium_casei': {'Nombre': 'Brevibacterium_casei_S18.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycyl-L-tyrosine',
#    'Guanine',
#    'L-histidine',
#    'Hypoxanthine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Thymidine',
#    'L-tryptophan',
#    'Zinc'],
#   'Tamaño_medio': 38,
#   'Crecimiento': 62.578491109534504},
#  'Corynebacterium_ammoniagenes': {'Nombre': 'Corynebacterium_ammoniagenes_DSM_20306.xml',
#   'Medio': ['4-Aminobenzoate',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'myo-inositol',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxal',
#    'Ubiquinone-8',
#    'sulfate',
#    'Thiamin',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 45.0641849947545},
#  'Corynebacterium_casei': {'Nombre': 'Corynebacterium_casei_UCMA_3821.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycylleucine',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Protoheme',
#    'hydrogenphosphate',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Zinc'],
#   'Tamaño_medio': 26,
#   'Crecimiento': 18.129969249692667},
#  'Lactobacillus_acidophilus': {'Nombre': 'Lactobacillus_acidophilus_NCFM.xml',
#   'Medio': ['4-Aminobenzoate',
#    'L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-glutamate',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'D-glucose',
#    'L-glutamine',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Ornithine',
#    'L-phenylalanine',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxal',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'Zinc'],
#   'Tamaño_medio': 45,
#   'Crecimiento': 43.11980613296209},
#  'Lactobacillus_amylolyticus': {'Nombre': 'Lactobacillus_amylolyticus_DSM_11664.xml',
#   'Medio': ['N-acetyl-D-glucosamine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-aspartate',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Ammonium',
#    'O2',
#    'L-phenylalanine',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxal',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 39,
#   'Crecimiento': 17.439839126924827},
#  'Lactobacillus_amylovorus': {'Nombre': 'Lactobacillus_amylovorus_GRL_1112.xml',
#   'Medio': ['2-Demethylmenaquinone 8',
#    'Adenine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamate',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycylproline',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'L-tryptophan',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 36.847362993882726},
#  'Lactobacillus_crispatus': {'Nombre': 'Lactobacillus_crispatus_ST1.xml',
#   'Medio': ['L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    '1,4-Dihydroxy-2-naphthoate',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamine',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'D-Mannitol',
#    'Menaquinone 7',
#    'NMN',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'Zinc'],
#   'Tamaño_medio': 50,
#   'Crecimiento': 47.17813269771683},
#  'Lactobacillus_delbrueckii': {'Nombre': 'Lactobacillus_delbrueckii_subsp_lactis_DSM_20072.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'Adenosylcobalamin',
#    'L-alanyl-L-glutamine',
#    'L-arginine',
#    'L-asparagine',
#    'Biotin',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Dextrin',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycylleucine',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-methionine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Orotate',
#    'L-phenylalanine',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 42,
#   'Crecimiento': 32.529056448652966},
#  'Lactobacillus_gasseri': {'Nombre': 'Lactobacillus_gasseri_SV_16A_US.xml',
#   'Medio': ['2-Oxoglutarate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamate',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Glycylproline',
#    'Guanine',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Putrescine',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'Spermidine',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 54.12800793219259},
#  'Lactobacillus_helveticus': {'Nombre': 'Lactobacillus_helveticus_R0052.xml',
#   'Medio': ['4-Amino-5-hydroxymethyl-2-methylpyrimidine',
#    'L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamate',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-asparagine',
#    'L-aspartate',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 42,
#   'Crecimiento': 41.40874223307062},
#  'Lactobacillus_johnsonii': {'Nombre': 'Lactobacillus_johnsonii_pf01.xml',
#   'Medio': ['L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamine',
#    'L-arginine',
#    'L-asparagine',
#    'L-aspartate',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycylproline',
#    'L-histidine',
#    'L-isoleucine',
#    'Inosine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Ornithine',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 43,
#   'Crecimiento': 41.631236641235354},
#  'Lactobacillus_kefiranofaciens': {'Nombre': 'Lactobacillus_kefiranofaciens_ZW3.xml',
#   'Medio': ['4-hydroxybenzoate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Citrate',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Guanine',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Riboflavin',
#    'D-glucitol',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 40.82352021806777},
#  'Lactococcus_lactis': {'Nombre': 'Lactococcus_lactis_subsp_lactis_YF11.xml',
#   'Medio': ['Adenosine',
#    'L-alanyl-L-aspartate',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycylproline',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Pyridoxal',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'uracil',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 26.38243464586346},
#  'Leuconostoc_citreum': {'Nombre': 'Leuconostoc_citreum_LBAE_E16.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-asparagine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamine',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'NMN',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 53.31312790582507},
#  'Leuconostoc_lactis': {'Nombre': 'Leuconostoc_lactis_KACC_91922.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    '2-Demethylmenaquinone 8',
#    'Adenosine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 41,
#   'Crecimiento': 27.797497889025585},
#  'Leuconostoc_mesenteroides': {'Nombre': 'Leuconostoc_mesenteroides_subsp_mesenteroides_J18.xml',
#   'Medio': ['Adenine',
#    'L-alanyl-L-glutamine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe2+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'L-histidine',
#    'L-isoleucine',
#    'Inosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'NMN',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-threonine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 40,
#   'Crecimiento': 64.97855699496846},
#  'Leuconostoc_pseudomesenteroides': {'Nombre': 'Leuconostoc_pseudomesenteroides_ERR2221296.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'L-asparagine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'L-glutamine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'NMN',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 45,
#   'Crecimiento': 56.603177071078115},
#  'Microbacterium_gubbeenense': {'Nombre': 'Microbacterium_gubbeenense_DSM_15944.xml',
#   'Medio': ['4-hydroxybenzoate',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycyl-L-tyrosine',
#    'Guanine',
#    'Hypoxanthine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nitrate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Zinc'],
#   'Tamaño_medio': 28,
#   'Crecimiento': 44.516900607755886},
#  'Pediococcus_acidilactici': {'Nombre': 'Pediococcus_acidilactici_MA18_5M.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'meso-2,6-Diaminoheptanedioate',
#    '4-Aminobenzoate',
#    '4-hydroxybenzoate',
#    'N-acetyl-D-glucosamine',
#    'L-alanine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'L-glutamate',
#    'Oxidized glutathione',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-methionine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'L-phenylalanine',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Putrescine',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 45,
#   'Crecimiento': 24.72171032101154},
#  'Pediococcus_pentosaceus': {'Nombre': 'Pediococcus_pentosaceus_IE_3.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'N-acetyl-D-glucosamine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Glycylphenylalanine',
#    'Glycylproline',
#    'Glycyl-L-tyrosine',
#    'L-isoleucine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 41,
#   'Crecimiento': 23.47122750296193},
#  'Propionibacterium_freudenreichii': {'Nombre': 'Propionibacterium_freudenreichii_subsp_shermanii_CIRM_BIA1.xml',
#   'Medio': ['2-Demethylmenaquinone 8',
#    'Adenosine',
#    'Adenosylcobalamin',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'L-tryptophan',
#    'Zinc'],
#   'Tamaño_medio': 36,
#   'Crecimiento': 59.06420456485616},
#  'Enterococcus_faecalis': {'Nombre': 'Enterococcus_faecalis_str_Symbioflor_1.xml',
#   'Medio': ['L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Dextrin',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Pyridoxal',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 35,
#   'Crecimiento': 45.56057922537775},
#  'Enterococcus_faecium': {'Nombre': 'Enterococcus_faecium_VRE_110.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'Adenosine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 39,
#   'Crecimiento': 33.335022046713306},
#  'Streptococcus_thermophilus': {'Nombre': 'Streptococcus_thermophilus_ND03.xml',
#   'Medio': ['L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Pyridoxal',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Xanthine',
#    'Zinc'],
#   'Tamaño_medio': 27,
#   'Crecimiento': 21.587090912941996},
#  'Bacillus_amyloliquefaciens': {'Nombre': 'Bacillus_amyloliquefaciens_subsp_amyloliquefaciens_DC_12.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Deoxyguanosine',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'glycogen, structure 2 (glycogenin-1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'Protoheme',
#    'Riboflavin',
#    'sulfate',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 26,
#   'Crecimiento': 30.746387429716346},
#  'Bacillus_atrophaeus': {'Nombre': 'Bacillus_atrophaeus_UCMB_5137.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'N-acetyl-D-glucosamine',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-methionine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Riboflavin',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 30,
#   'Crecimiento': 37.79845020998603},
#  'Bacillus_licheniformis': {'Nombre': 'Bacillus_licheniformis_HRBL_15TDI7.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Hypoxanthine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'octadecanoate (n-C18:0)',
#    'pectins',
#    'Protoheme',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Thiamin',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 29,
#   'Crecimiento': 60.26379189598235},
#  'Bacillus_mojavensis': {'Nombre': 'Bacillus_mojavensis_RO_H_1.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-methionine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'Protoheme',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 28,
#   'Crecimiento': 32.493986636677704},
#  'Bacillus_pumilus': {'Nombre': 'Bacillus_pumilus_TUAT1.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nitrate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Putrescine',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'uracil',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 38,
#   'Crecimiento': 66.9391866143888},
#  'Bacillus_smithii': {'Nombre': 'Bacillus_smithii_7_3_47FAA.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycylleucine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'hydrogenphosphate',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Taurine',
#    'Thiamin',
#    'Zinc'],
#   'Tamaño_medio': 29,
#   'Crecimiento': 40.442733887559164},
#  'Bacillus_subtilis': {'Nombre': 'Bacillus_subtilis_subsp_subtilis_str_SMY.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'pectins',
#    'Protoheme',
#    'sulfate',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 26,
#   'Crecimiento': 25.051218708494904},
#  'Bacillus_vallismortis': {'Nombre': 'Bacillus_vallismortis_DV1_F_3.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    '2-Demethylmenaquinone 8',
#    'N-acetyl-D-glucosamine',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Guanine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-Rhamnose',
#    'Siroheme',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 35,
#   'Crecimiento': 28.765618643102016},
#  'Bacillus_velezensis': {'Nombre': 'Bacillus_velezensis_UCMB5036.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Hypoxanthine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Riboflavin',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Thiamin',
#    'thiosulfate(2-)',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 30,
#   'Crecimiento': 30.710293496400556},
#  'Geobacillus_stearothermophilus': {'Nombre': 'Geobacillus_stearothermophilus_ATCC_7953.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    '4-hydroxybenzoate',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Guanine',
#    'Hypoxanthine',
#    'Chicory inulin',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'uracil',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 33.72374954935539},
#  'Lysinibacillus_fusiformis': {'Nombre': 'Lysinibacillus_fusiformis_ZB2.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'meso-2,6-Diaminoheptanedioate',
#    '4-hydroxybenzoate',
#    'N-acetyl-D-glucosamine',
#    'L-alanyl-L-leucine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-tyrosine',
#    'Inosine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'O2',
#    'Protoheme',
#    'hydrogenphosphate',
#    'Pyridoxal',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'thiosulfate(2-)',
#    'Uridine',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 25.520363850241523}}

# %% [markdown]
# A partir del resultado anterior, ordenamos las especies de mejor a peor, nuevamente en función del número de metabolitos en el medio y del crecimiento predicho (del mejor modelo).

# %%
# Definir la función de ordenamiento
def criterio_ordenamiento(especie, mi_diccionario = mejor_modelo):
    return (mi_diccionario[especie]['Tamaño_medio'], -mi_diccionario[especie]['Crecimiento'])

# Obtener las claves ordenadas
especies_ordenadas = sorted(mejor_modelo.keys(), key=criterio_ordenamiento)

#La lista de especies, ordenadas de mejor a peor, queda:
print("Claves ordenadas:", especies_ordenadas)
# Out:
# Claves ordenadas: ['Bacillus_amyloliquefaciens', 'Bacillus_subtilis', 'Corynebacterium_casei', 'Streptococcus_thermophilus', 'Microbacterium_gubbeenense', 'Bifidobacterium_longum', 'Bacillus_mojavensis', 'Bacillus_licheniformis', 'Bifidobacterium_thermophilum', 'Bacillus_smithii', 'Bacillus_atrophaeus', 'Bacillus_velezensis', 'Bifidobacterium_adolescentis', 'Corynebacterium_ammoniagenes', 'Geobacillus_stearothermophilus', 'Bifidobacterium_bifidum', 'Lactococcus_lactis', 'Lysinibacillus_fusiformis', 'Bifidobacterium_breve', 'Enterococcus_faecalis', 'Bacillus_vallismortis', 'Bifidobacterium_animalis', 'Propionibacterium_freudenreichii', 'Bifidobacterium_pseudolongum', 'Hafnia_alvei', 'Bacillus_pumilus', 'Brevibacterium_casei', 'Enterococcus_faecium', 'Lactobacillus_amylolyticus', 'Leuconostoc_mesenteroides', 'Leuconostoc_lactis', 'Pediococcus_pentosaceus', 'Lactobacillus_helveticus', 'Lactobacillus_delbrueckii', 'Lactobacillus_johnsonii', 'Lactobacillus_gasseri', 'Leuconostoc_citreum', 'Lactobacillus_kefiranofaciens', 'Lactobacillus_amylovorus', 'Leuconostoc_pseudomesenteroides', 'Lactobacillus_acidophilus', 'Pediococcus_acidilactici', 'Lactobacillus_crispatus']

# %% [markdown]
# Comprobamos que realmente están ordenadas en función del tamaño medio y el crecimiento

# %%
print("Tamaño_medio\tCrecimiento")
for especie in especies_ordenadas:
    print(mejor_modelo[especie]["Tamaño_medio"],"\t", mejor_modelo[especie]["Crecimiento"])
# Out:
# Tamaño_medio	Crecimiento
# 26 	 30.746387429716346
# 26 	 25.051218708494904
# 26 	 18.129969249692667
# 27 	 21.587090912941996
# 28 	 44.516900607755886
# 28 	 34.414649951689135
# 28 	 32.493986636677704
# 29 	 60.26379189598235
# 29 	 55.93248115621994
# 29 	 40.442733887559164
# 30 	 37.79845020998603
# 30 	 30.710293496400556
# 30 	 30.702585378651595
# 32 	 45.0641849947545
# 32 	 33.72374954935539
# 32 	 29.89725859404358
# 32 	 26.38243464586346
# 32 	 25.520363850241523
# 33 	 25.374629475378395
# 35 	 45.56057922537775
# 35 	 28.765618643102016
# 35 	 27.525228753425456
# 36 	 59.06420456485616
# 36 	 41.748870935399424
# 37 	 47.442286930309436
# 38 	 66.9391866143888
# 38 	 62.578491109534504
# 39 	 33.335022046713306
# 39 	 17.439839126924827
# 40 	 64.97855699496846
# 41 	 27.797497889025585
# 41 	 23.47122750296193
# 42 	 41.40874223307062
# 42 	 32.529056448652966
# 43 	 41.631236641235354
# 44 	 54.12800793219259
# 44 	 53.31312790582507
# 44 	 40.82352021806777
# 44 	 36.847362993882726
# 45 	 56.603177071078115
# 45 	 43.11980613296209
# 45 	 24.72171032101154
# 50 	 47.17813269771683

# %% [markdown]
# Ahora creamos un diccionario "mejor_especie", con la misma información que "mejor modelo" pero ordenado:

# %%
mejor_especie = {}
for especie in especies_ordenadas:
    mejor_especie[especie] = mejor_modelo[especie]

# %%
mejor_especie
# Out:
# {'Bacillus_amyloliquefaciens': {'Nombre': 'Bacillus_amyloliquefaciens_subsp_amyloliquefaciens_DC_12.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Deoxyguanosine',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'glycogen, structure 2 (glycogenin-1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'Protoheme',
#    'Riboflavin',
#    'sulfate',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 26,
#   'Crecimiento': 30.746387429716346},
#  'Bacillus_subtilis': {'Nombre': 'Bacillus_subtilis_subsp_subtilis_str_SMY.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'pectins',
#    'Protoheme',
#    'sulfate',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 26,
#   'Crecimiento': 25.051218708494904},
#  'Corynebacterium_casei': {'Nombre': 'Corynebacterium_casei_UCMA_3821.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycylleucine',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Protoheme',
#    'hydrogenphosphate',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Zinc'],
#   'Tamaño_medio': 26,
#   'Crecimiento': 18.129969249692667},
#  'Streptococcus_thermophilus': {'Nombre': 'Streptococcus_thermophilus_ND03.xml',
#   'Medio': ['L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Pyridoxal',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Xanthine',
#    'Zinc'],
#   'Tamaño_medio': 27,
#   'Crecimiento': 21.587090912941996},
#  'Microbacterium_gubbeenense': {'Nombre': 'Microbacterium_gubbeenense_DSM_15944.xml',
#   'Medio': ['4-hydroxybenzoate',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycyl-L-tyrosine',
#    'Guanine',
#    'Hypoxanthine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nitrate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Zinc'],
#   'Tamaño_medio': 28,
#   'Crecimiento': 44.516900607755886},
#  'Bifidobacterium_longum': {'Nombre': 'Bifidobacterium_longum_subsp_longum_NCIMB8809.xml',
#   'Medio': ['Adenosylcobalamin',
#    'L-alanyl-L-histidine',
#    'Larch arabinogalactan',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Protoheme',
#    'hydrogenphosphate',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 28,
#   'Crecimiento': 34.414649951689135},
#  'Bacillus_mojavensis': {'Nombre': 'Bacillus_mojavensis_RO_H_1.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-methionine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'Protoheme',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 28,
#   'Crecimiento': 32.493986636677704},
#  'Bacillus_licheniformis': {'Nombre': 'Bacillus_licheniformis_HRBL_15TDI7.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Hypoxanthine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'octadecanoate (n-C18:0)',
#    'pectins',
#    'Protoheme',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Thiamin',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 29,
#   'Crecimiento': 60.26379189598235},
#  'Bifidobacterium_thermophilum': {'Nombre': 'Bifidobacterium_thermophilum_RBL67.xml',
#   'Medio': ['Adenine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Guanine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Urea',
#    'Zinc'],
#   'Tamaño_medio': 29,
#   'Crecimiento': 55.93248115621994},
#  'Bacillus_smithii': {'Nombre': 'Bacillus_smithii_7_3_47FAA.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycylleucine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'hydrogenphosphate',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Taurine',
#    'Thiamin',
#    'Zinc'],
#   'Tamaño_medio': 29,
#   'Crecimiento': 40.442733887559164},
#  'Bacillus_atrophaeus': {'Nombre': 'Bacillus_atrophaeus_UCMB_5137.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'N-acetyl-D-glucosamine',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-methionine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Riboflavin',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 30,
#   'Crecimiento': 37.79845020998603},
#  'Bacillus_velezensis': {'Nombre': 'Bacillus_velezensis_UCMB5036.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Hypoxanthine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Riboflavin',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Thiamin',
#    'thiosulfate(2-)',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 30,
#   'Crecimiento': 30.710293496400556},
#  'Bifidobacterium_adolescentis': {'Nombre': 'Bifidobacterium_adolescentis_L2_32.xml',
#   'Medio': ['4-Aminobenzoate',
#    'Adenine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Guanine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Spermidine',
#    'Resistant starch',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 30,
#   'Crecimiento': 30.702585378651595},
#  'Corynebacterium_ammoniagenes': {'Nombre': 'Corynebacterium_ammoniagenes_DSM_20306.xml',
#   'Medio': ['4-Aminobenzoate',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'myo-inositol',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxal',
#    'Ubiquinone-8',
#    'sulfate',
#    'Thiamin',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 45.0641849947545},
#  'Geobacillus_stearothermophilus': {'Nombre': 'Geobacillus_stearothermophilus_ATCC_7953.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    '4-hydroxybenzoate',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Guanine',
#    'Hypoxanthine',
#    'Chicory inulin',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'uracil',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 33.72374954935539},
#  'Bifidobacterium_bifidum': {'Nombre': 'Bifidobacterium_bifidum_S17.xml',
#   'Medio': ['L-alanyl-L-histidine',
#    'Larch arabinogalactan',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycyl-L-methionine',
#    'GlcNAc-alpha-1,4-Core 2',
#    'Hypoxanthine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 29.89725859404358},
#  'Lactococcus_lactis': {'Nombre': 'Lactococcus_lactis_subsp_lactis_YF11.xml',
#   'Medio': ['Adenosine',
#    'L-alanyl-L-aspartate',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycylproline',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Pyridoxal',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'uracil',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 26.38243464586346},
#  'Lysinibacillus_fusiformis': {'Nombre': 'Lysinibacillus_fusiformis_ZB2.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'meso-2,6-Diaminoheptanedioate',
#    '4-hydroxybenzoate',
#    'N-acetyl-D-glucosamine',
#    'L-alanyl-L-leucine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-tyrosine',
#    'Inosine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'O2',
#    'Protoheme',
#    'hydrogenphosphate',
#    'Pyridoxal',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'thiosulfate(2-)',
#    'Uridine',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 25.520363850241523},
#  'Bifidobacterium_breve': {'Nombre': 'Bifidobacterium_breve_UCC2003_NCIMB8807.xml',
#   'Medio': ['Adenosylcobalamin',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'Amylopectin, 900 repeat units',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycyl-L-methionine',
#    'Glycylproline',
#    'Hypoxanthine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 33,
#   'Crecimiento': 25.374629475378395},
#  'Enterococcus_faecalis': {'Nombre': 'Enterococcus_faecalis_str_Symbioflor_1.xml',
#   'Medio': ['L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Dextrin',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Pyridoxal',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 35,
#   'Crecimiento': 45.56057922537775},
#  'Bacillus_vallismortis': {'Nombre': 'Bacillus_vallismortis_DV1_F_3.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    '2-Demethylmenaquinone 8',
#    'N-acetyl-D-glucosamine',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Guanine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-Rhamnose',
#    'Siroheme',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 35,
#   'Crecimiento': 28.765618643102016},
#  'Bifidobacterium_animalis': {'Nombre': 'Bifidobacterium_animalis_subsp_lactis_HN019.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 35,
#   'Crecimiento': 27.525228753425456},
#  'Propionibacterium_freudenreichii': {'Nombre': 'Propionibacterium_freudenreichii_subsp_shermanii_CIRM_BIA1.xml',
#   'Medio': ['2-Demethylmenaquinone 8',
#    'Adenosine',
#    'Adenosylcobalamin',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'L-tryptophan',
#    'Zinc'],
#   'Tamaño_medio': 36,
#   'Crecimiento': 59.06420456485616},
#  'Bifidobacterium_pseudolongum': {'Nombre': 'Bifidobacterium_pseudolongum_subsp_Pseudolongum_DSM_20099.xml',
#   'Medio': ['Adenine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-asparagine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe2+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-glutamine',
#    'Guanine',
#    'L-histidine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Ornithine',
#    'Orotate',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)',
#    'Riboflavin',
#    'sulfate',
#    'Thiamin',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 36,
#   'Crecimiento': 41.748870935399424},
#  'Hafnia_alvei': {'Nombre': 'Hafnia_alvei_HUMV_5920.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-Rhamnose',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'tetradecanoate (n-C14:0)',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 37,
#   'Crecimiento': 47.442286930309436},
#  'Bacillus_pumilus': {'Nombre': 'Bacillus_pumilus_TUAT1.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nitrate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Putrescine',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'uracil',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 38,
#   'Crecimiento': 66.9391866143888},
#  'Brevibacterium_casei': {'Nombre': 'Brevibacterium_casei_S18.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycyl-L-tyrosine',
#    'Guanine',
#    'L-histidine',
#    'Hypoxanthine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Thymidine',
#    'L-tryptophan',
#    'Zinc'],
#   'Tamaño_medio': 38,
#   'Crecimiento': 62.578491109534504},
#  'Enterococcus_faecium': {'Nombre': 'Enterococcus_faecium_VRE_110.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'Adenosine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 39,
#   'Crecimiento': 33.335022046713306},
#  'Lactobacillus_amylolyticus': {'Nombre': 'Lactobacillus_amylolyticus_DSM_11664.xml',
#   'Medio': ['N-acetyl-D-glucosamine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-aspartate',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Ammonium',
#    'O2',
#    'L-phenylalanine',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxal',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 39,
#   'Crecimiento': 17.439839126924827},
#  'Leuconostoc_mesenteroides': {'Nombre': 'Leuconostoc_mesenteroides_subsp_mesenteroides_J18.xml',
#   'Medio': ['Adenine',
#    'L-alanyl-L-glutamine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe2+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'L-histidine',
#    'L-isoleucine',
#    'Inosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'NMN',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-threonine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 40,
#   'Crecimiento': 64.97855699496846},
#  'Leuconostoc_lactis': {'Nombre': 'Leuconostoc_lactis_KACC_91922.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    '2-Demethylmenaquinone 8',
#    'Adenosine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 41,
#   'Crecimiento': 27.797497889025585},
#  'Pediococcus_pentosaceus': {'Nombre': 'Pediococcus_pentosaceus_IE_3.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'N-acetyl-D-glucosamine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Glycylphenylalanine',
#    'Glycylproline',
#    'Glycyl-L-tyrosine',
#    'L-isoleucine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 41,
#   'Crecimiento': 23.47122750296193},
#  'Lactobacillus_helveticus': {'Nombre': 'Lactobacillus_helveticus_R0052.xml',
#   'Medio': ['4-Amino-5-hydroxymethyl-2-methylpyrimidine',
#    'L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamate',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-asparagine',
#    'L-aspartate',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 42,
#   'Crecimiento': 41.40874223307062},
#  'Lactobacillus_delbrueckii': {'Nombre': 'Lactobacillus_delbrueckii_subsp_lactis_DSM_20072.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'Adenosylcobalamin',
#    'L-alanyl-L-glutamine',
#    'L-arginine',
#    'L-asparagine',
#    'Biotin',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Dextrin',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycylleucine',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-methionine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Orotate',
#    'L-phenylalanine',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 42,
#   'Crecimiento': 32.529056448652966},
#  'Lactobacillus_johnsonii': {'Nombre': 'Lactobacillus_johnsonii_pf01.xml',
#   'Medio': ['L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamine',
#    'L-arginine',
#    'L-asparagine',
#    'L-aspartate',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycylproline',
#    'L-histidine',
#    'L-isoleucine',
#    'Inosine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Ornithine',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 43,
#   'Crecimiento': 41.631236641235354},
#  'Lactobacillus_gasseri': {'Nombre': 'Lactobacillus_gasseri_SV_16A_US.xml',
#   'Medio': ['2-Oxoglutarate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamate',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Glycylproline',
#    'Guanine',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Putrescine',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'Spermidine',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 54.12800793219259},
#  'Leuconostoc_citreum': {'Nombre': 'Leuconostoc_citreum_LBAE_E16.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-asparagine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamine',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'NMN',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 53.31312790582507},
#  'Lactobacillus_kefiranofaciens': {'Nombre': 'Lactobacillus_kefiranofaciens_ZW3.xml',
#   'Medio': ['4-hydroxybenzoate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Citrate',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Guanine',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Riboflavin',
#    'D-glucitol',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 40.82352021806777},
#  'Lactobacillus_amylovorus': {'Nombre': 'Lactobacillus_amylovorus_GRL_1112.xml',
#   'Medio': ['2-Demethylmenaquinone 8',
#    'Adenine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamate',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycylproline',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'L-tryptophan',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 36.847362993882726},
#  'Leuconostoc_pseudomesenteroides': {'Nombre': 'Leuconostoc_pseudomesenteroides_ERR2221296.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'L-asparagine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'L-glutamine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'NMN',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 45,
#   'Crecimiento': 56.603177071078115},
#  'Lactobacillus_acidophilus': {'Nombre': 'Lactobacillus_acidophilus_NCFM.xml',
#   'Medio': ['4-Aminobenzoate',
#    'L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-glutamate',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'D-glucose',
#    'L-glutamine',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Ornithine',
#    'L-phenylalanine',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxal',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'Zinc'],
#   'Tamaño_medio': 45,
#   'Crecimiento': 43.11980613296209},
#  'Pediococcus_acidilactici': {'Nombre': 'Pediococcus_acidilactici_MA18_5M.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'meso-2,6-Diaminoheptanedioate',
#    '4-Aminobenzoate',
#    '4-hydroxybenzoate',
#    'N-acetyl-D-glucosamine',
#    'L-alanine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'L-glutamate',
#    'Oxidized glutathione',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-methionine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'L-phenylalanine',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Putrescine',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 45,
#   'Crecimiento': 24.72171032101154},
#  'Lactobacillus_crispatus': {'Nombre': 'Lactobacillus_crispatus_ST1.xml',
#   'Medio': ['L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    '1,4-Dihydroxy-2-naphthoate',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamine',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'D-Mannitol',
#    'Menaquinone 7',
#    'NMN',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'Zinc'],
#   'Tamaño_medio': 50,
#   'Crecimiento': 47.17813269771683}}

# %% [markdown]
# ## Exportamos los resultados

# %%
#Exportamos el resultado a json
with open('Mejores_especies_minimal.json', 'w') as archivo:
    json.dump(mejor_especie, archivo)

# %% [markdown]
# # Creación del Excel Final

# %% [markdown]
# En este archivo vamos a sintetizar la información que contiene el diccionario "mejor_especie"

# %%
# Crear un nuevo libro de Excel y seleccionar la hoja de trabajo
workbook = openpyxl.load_workbook("Resultado_Initial_Approach_Minimal.xlsx")
hoja_trabajo = workbook.active

# Rellenamos por cada especie(fila):
# Columna 1 con los nombres de las especies
# Columna 2 mejor modelo
# Columna 3Tamaño del medio
# Columna 3 Crecimiento predicho
for i, nombre  in enumerate(mejor_especie.keys(), start=2):
    info_especie = mejor_especie[nombre] #Diccionario de la especie
    hoja_trabajo.cell(row=i, column=1, value=nombre)
    hoja_trabajo.cell(row=i, column=2, value=info_especie["Nombre"])
    medio = ", ".join(info_especie["Medio"])
    hoja_trabajo.cell(row=i, column=3, value=medio)
    hoja_trabajo.cell(row=i, column=4, value=info_especie["Tamaño_medio"])
    hoja_trabajo.cell(row=i, column=5, value=info_especie["Crecimiento"])

# Guardar el libro de Excel
workbook.save('Resultado_Initial_Approach_Minimal.xlsx')

# %% [markdown]
# # DESGLOSE INITIAL APPROACH MINIMAL MEDIA

# %% [markdown]
# El objetivo es reorganizar la tabla obtenida del análisis anterior, de manera que se incluya una columna para cada metabolito. De esta manera, para cada organismo se indicará si el medio contiene un metabolito dado en función del valor de su columna:
# - 1: lo contiene
# - 0: no lo contiene

# %% [markdown]
# ## Importamos resultado

# %%
#Importamos los resultados
with open('Mejores_especies_minimal.json', 'r') as archivo:
    resultados = json.load(archivo)

# %%
resultados
# Out:
# {'Bacillus_amyloliquefaciens': {'Nombre': 'Bacillus_amyloliquefaciens_subsp_amyloliquefaciens_DC_12.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Deoxyguanosine',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'glycogen, structure 2 (glycogenin-1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'Protoheme',
#    'Riboflavin',
#    'sulfate',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 26,
#   'Crecimiento': 30.746387429716346},
#  'Bacillus_subtilis': {'Nombre': 'Bacillus_subtilis_subsp_subtilis_str_SMY.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'pectins',
#    'Protoheme',
#    'sulfate',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 26,
#   'Crecimiento': 25.051218708494904},
#  'Corynebacterium_casei': {'Nombre': 'Corynebacterium_casei_UCMA_3821.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycylleucine',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Protoheme',
#    'hydrogenphosphate',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Zinc'],
#   'Tamaño_medio': 26,
#   'Crecimiento': 18.129969249692667},
#  'Streptococcus_thermophilus': {'Nombre': 'Streptococcus_thermophilus_ND03.xml',
#   'Medio': ['L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Pyridoxal',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Xanthine',
#    'Zinc'],
#   'Tamaño_medio': 27,
#   'Crecimiento': 21.587090912941996},
#  'Microbacterium_gubbeenense': {'Nombre': 'Microbacterium_gubbeenense_DSM_15944.xml',
#   'Medio': ['4-hydroxybenzoate',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycyl-L-tyrosine',
#    'Guanine',
#    'Hypoxanthine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nitrate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Zinc'],
#   'Tamaño_medio': 28,
#   'Crecimiento': 44.516900607755886},
#  'Bifidobacterium_longum': {'Nombre': 'Bifidobacterium_longum_subsp_longum_NCIMB8809.xml',
#   'Medio': ['Adenosylcobalamin',
#    'L-alanyl-L-histidine',
#    'Larch arabinogalactan',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Protoheme',
#    'hydrogenphosphate',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 28,
#   'Crecimiento': 34.414649951689135},
#  'Bacillus_mojavensis': {'Nombre': 'Bacillus_mojavensis_RO_H_1.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-methionine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'Protoheme',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 28,
#   'Crecimiento': 32.493986636677704},
#  'Bacillus_licheniformis': {'Nombre': 'Bacillus_licheniformis_HRBL_15TDI7.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Hypoxanthine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'octadecanoate (n-C18:0)',
#    'pectins',
#    'Protoheme',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Thiamin',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 29,
#   'Crecimiento': 60.26379189598235},
#  'Bifidobacterium_thermophilum': {'Nombre': 'Bifidobacterium_thermophilum_RBL67.xml',
#   'Medio': ['Adenine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Guanine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Urea',
#    'Zinc'],
#   'Tamaño_medio': 29,
#   'Crecimiento': 55.93248115621994},
#  'Bacillus_smithii': {'Nombre': 'Bacillus_smithii_7_3_47FAA.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycylleucine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'hydrogenphosphate',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Taurine',
#    'Thiamin',
#    'Zinc'],
#   'Tamaño_medio': 29,
#   'Crecimiento': 40.442733887559164},
#  'Bacillus_atrophaeus': {'Nombre': 'Bacillus_atrophaeus_UCMB_5137.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'N-acetyl-D-glucosamine',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-methionine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Riboflavin',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 30,
#   'Crecimiento': 37.79845020998603},
#  'Bacillus_velezensis': {'Nombre': 'Bacillus_velezensis_UCMB5036.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Hypoxanthine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Riboflavin',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Thiamin',
#    'thiosulfate(2-)',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 30,
#   'Crecimiento': 30.710293496400556},
#  'Bifidobacterium_adolescentis': {'Nombre': 'Bifidobacterium_adolescentis_L2_32.xml',
#   'Medio': ['4-Aminobenzoate',
#    'Adenine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Guanine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Spermidine',
#    'Resistant starch',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 30,
#   'Crecimiento': 30.702585378651595},
#  'Corynebacterium_ammoniagenes': {'Nombre': 'Corynebacterium_ammoniagenes_DSM_20306.xml',
#   'Medio': ['4-Aminobenzoate',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'myo-inositol',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxal',
#    'Ubiquinone-8',
#    'sulfate',
#    'Thiamin',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 45.0641849947545},
#  'Geobacillus_stearothermophilus': {'Nombre': 'Geobacillus_stearothermophilus_ATCC_7953.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    '4-hydroxybenzoate',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Guanine',
#    'Hypoxanthine',
#    'Chicory inulin',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'uracil',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 33.72374954935539},
#  'Bifidobacterium_bifidum': {'Nombre': 'Bifidobacterium_bifidum_S17.xml',
#   'Medio': ['L-alanyl-L-histidine',
#    'Larch arabinogalactan',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycyl-L-methionine',
#    'GlcNAc-alpha-1,4-Core 2',
#    'Hypoxanthine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-Rhamnose',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 29.89725859404358},
#  'Lactococcus_lactis': {'Nombre': 'Lactococcus_lactis_subsp_lactis_YF11.xml',
#   'Medio': ['Adenosine',
#    'L-alanyl-L-aspartate',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycylproline',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Pyridoxal',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'uracil',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 26.38243464586346},
#  'Lysinibacillus_fusiformis': {'Nombre': 'Lysinibacillus_fusiformis_ZB2.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'meso-2,6-Diaminoheptanedioate',
#    '4-hydroxybenzoate',
#    'N-acetyl-D-glucosamine',
#    'L-alanyl-L-leucine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-tyrosine',
#    'Inosine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'O2',
#    'Protoheme',
#    'hydrogenphosphate',
#    'Pyridoxal',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'thiosulfate(2-)',
#    'Uridine',
#    'Zinc'],
#   'Tamaño_medio': 32,
#   'Crecimiento': 25.520363850241523},
#  'Bifidobacterium_breve': {'Nombre': 'Bifidobacterium_breve_UCC2003_NCIMB8807.xml',
#   'Medio': ['Adenosylcobalamin',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'Amylopectin, 900 repeat units',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycyl-L-methionine',
#    'Glycylproline',
#    'Hypoxanthine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 33,
#   'Crecimiento': 25.374629475378395},
#  'Enterococcus_faecalis': {'Nombre': 'Enterococcus_faecalis_str_Symbioflor_1.xml',
#   'Medio': ['L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Dextrin',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Pyridoxal',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 35,
#   'Crecimiento': 45.56057922537775},
#  'Bacillus_vallismortis': {'Nombre': 'Bacillus_vallismortis_DV1_F_3.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    '2-Demethylmenaquinone 8',
#    'N-acetyl-D-glucosamine',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Cytidine',
#    'Deoxyguanosine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Guanine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-Rhamnose',
#    'Siroheme',
#    'sulfate',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'Thiamin',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 35,
#   'Crecimiento': 28.765618643102016},
#  'Bifidobacterium_animalis': {'Nombre': 'Bifidobacterium_animalis_subsp_lactis_HN019.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 35,
#   'Crecimiento': 27.525228753425456},
#  'Propionibacterium_freudenreichii': {'Nombre': 'Propionibacterium_freudenreichii_subsp_shermanii_CIRM_BIA1.xml',
#   'Medio': ['2-Demethylmenaquinone 8',
#    'Adenosine',
#    'Adenosylcobalamin',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'L-tryptophan',
#    'Zinc'],
#   'Tamaño_medio': 36,
#   'Crecimiento': 59.06420456485616},
#  'Bifidobacterium_pseudolongum': {'Nombre': 'Bifidobacterium_pseudolongum_subsp_Pseudolongum_DSM_20099.xml',
#   'Medio': ['Adenine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-asparagine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe2+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-glutamine',
#    'Guanine',
#    'L-histidine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Ornithine',
#    'Orotate',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)',
#    'Riboflavin',
#    'sulfate',
#    'Thiamin',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 36,
#   'Crecimiento': 41.748870935399424},
#  'Hafnia_alvei': {'Nombre': 'Hafnia_alvei_HUMV_5920.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'Adenosine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-Rhamnose',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'tetradecanoate (n-C14:0)',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 37,
#   'Crecimiento': 47.442286930309436},
#  'Bacillus_pumilus': {'Nombre': 'Bacillus_pumilus_TUAT1.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Nitrate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    'Putrescine',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'uracil',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 38,
#   'Crecimiento': 66.9391866143888},
#  'Brevibacterium_casei': {'Nombre': 'Brevibacterium_casei_S18.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'Glycyl-L-methionine',
#    'Glycyl-L-tyrosine',
#    'Guanine',
#    'L-histidine',
#    'Hypoxanthine',
#    'potassium',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'Thymidine',
#    'L-tryptophan',
#    'Zinc'],
#   'Tamaño_medio': 38,
#   'Crecimiento': 62.578491109534504},
#  'Enterococcus_faecium': {'Nombre': 'Enterococcus_faecium_VRE_110.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'Adenosine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 39,
#   'Crecimiento': 33.335022046713306},
#  'Lactobacillus_amylolyticus': {'Nombre': 'Lactobacillus_amylolyticus_DSM_11664.xml',
#   'Medio': ['N-acetyl-D-glucosamine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-aspartate',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Ammonium',
#    'O2',
#    'L-phenylalanine',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxal',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 39,
#   'Crecimiento': 17.439839126924827},
#  'Leuconostoc_mesenteroides': {'Nombre': 'Leuconostoc_mesenteroides_subsp_mesenteroides_J18.xml',
#   'Medio': ['Adenine',
#    'L-alanyl-L-glutamine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe2+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'L-histidine',
#    'L-isoleucine',
#    'Inosine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'NMN',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-threonine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 40,
#   'Crecimiento': 64.97855699496846},
#  'Leuconostoc_lactis': {'Nombre': 'Leuconostoc_lactis_KACC_91922.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    '2-Demethylmenaquinone 8',
#    'Adenosine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycyl-L-methionine',
#    'Glycylphenylalanine',
#    'Glycyl-L-tyrosine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'NMN',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 41,
#   'Crecimiento': 27.797497889025585},
#  'Pediococcus_pentosaceus': {'Nombre': 'Pediococcus_pentosaceus_IE_3.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    '4-hydroxybenzoate',
#    'N-acetyl-D-glucosamine',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Glycylphenylalanine',
#    'Glycylproline',
#    'Glycyl-L-tyrosine',
#    'L-isoleucine',
#    'potassium',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-valine',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 41,
#   'Crecimiento': 23.47122750296193},
#  'Lactobacillus_helveticus': {'Nombre': 'Lactobacillus_helveticus_R0052.xml',
#   'Medio': ['4-Amino-5-hydroxymethyl-2-methylpyrimidine',
#    'L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamate',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-asparagine',
#    'L-aspartate',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 42,
#   'Crecimiento': 41.40874223307062},
#  'Lactobacillus_delbrueckii': {'Nombre': 'Lactobacillus_delbrueckii_subsp_lactis_DSM_20072.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'Adenosylcobalamin',
#    'L-alanyl-L-glutamine',
#    'L-arginine',
#    'L-asparagine',
#    'Biotin',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Dextrin',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycylleucine',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-methionine',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'Orotate',
#    'L-phenylalanine',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 42,
#   'Crecimiento': 32.529056448652966},
#  'Lactobacillus_johnsonii': {'Nombre': 'Lactobacillus_johnsonii_pf01.xml',
#   'Medio': ['L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamine',
#    'L-arginine',
#    'L-asparagine',
#    'L-aspartate',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycylproline',
#    'L-histidine',
#    'L-isoleucine',
#    'Inosine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'Ornithine',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 43,
#   'Crecimiento': 41.631236641235354},
#  'Lactobacillus_gasseri': {'Nombre': 'Lactobacillus_gasseri_SV_16A_US.xml',
#   'Medio': ['2-Oxoglutarate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'L-cysteine',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamate',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'Glycylproline',
#    'Guanine',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Putrescine',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'Spermidine',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 54.12800793219259},
#  'Leuconostoc_citreum': {'Nombre': 'Leuconostoc_citreum_LBAE_E16.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'L-asparagine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamine',
#    'Glycerol 3-phosphate',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'NMN',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 53.31312790582507},
#  'Lactobacillus_kefiranofaciens': {'Nombre': 'Lactobacillus_kefiranofaciens_ZW3.xml',
#   'Medio': ['4-hydroxybenzoate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-leucine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Citrate',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Guanine',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Riboflavin',
#    'D-glucitol',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 40.82352021806777},
#  'Lactobacillus_amylovorus': {'Nombre': 'Lactobacillus_amylovorus_GRL_1112.xml',
#   'Medio': ['2-Demethylmenaquinone 8',
#    'Adenine',
#    'L-alanyl-L-histidine',
#    'L-alanyl-L-leucine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamate',
#    'Glycerol 3-phosphate',
#    'Glycyl-L-glutamine',
#    'Glycylleucine',
#    'Glycylproline',
#    'Glycyl-L-tyrosine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-lysine',
#    'L-methionyl-L-alanine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 8',
#    'Nicotinate',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#    'L-tryptophan',
#    'uracil',
#    'L-valine',
#    'Zinc'],
#   'Tamaño_medio': 44,
#   'Crecimiento': 36.847362993882726},
#  'Leuconostoc_pseudomesenteroides': {'Nombre': 'Leuconostoc_pseudomesenteroides_ERR2221296.xml',
#   'Medio': ['meso-2,6-Diaminoheptanedioate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-histidine',
#    'L-arginine',
#    'L-asparagine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'Folate',
#    'D-Glucosamine',
#    'D-glucose',
#    'L-glutamine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'NMN',
#    'O2',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'Putrescine',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 45,
#   'Crecimiento': 56.603177071078115},
#  'Lactobacillus_acidophilus': {'Nombre': 'Lactobacillus_acidophilus_NCFM.xml',
#   'Medio': ['4-Aminobenzoate',
#    'L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-glutamate',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    'Fe2+',
#    'D-glucose',
#    'L-glutamine',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycyl-L-glutamine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'Nicotinate',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'Ornithine',
#    'L-phenylalanine',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxal',
#    'Riboflavin',
#    'L-serine',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'Zinc'],
#   'Tamaño_medio': 45,
#   'Crecimiento': 43.11980613296209},
#  'Pediococcus_acidilactici': {'Nombre': 'Pediococcus_acidilactici_MA18_5M.xml',
#   'Medio': ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#    'meso-2,6-Diaminoheptanedioate',
#    '4-Aminobenzoate',
#    '4-hydroxybenzoate',
#    'N-acetyl-D-glucosamine',
#    'L-alanine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'cytosine',
#    'Cu2+',
#    'Fe2+',
#    'Fe3+',
#    'D-glucose',
#    'L-glutamate',
#    'Oxidized glutathione',
#    'L-histidine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-methionine',
#    'magnesium',
#    'Mn2+',
#    'Menaquinone 7',
#    'Nicotinate',
#    'L-phenylalanine',
#    'Protoheme',
#    'hydrogenphosphate',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Putrescine',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-threonine',
#    'L-tryptophan',
#    'L-tyrosine',
#    'L-valine',
#    'aldehydo-D-xylose',
#    'Zinc'],
#   'Tamaño_medio': 45,
#   'Crecimiento': 24.72171032101154},
#  'Lactobacillus_crispatus': {'Nombre': 'Lactobacillus_crispatus_ST1.xml',
#   'Medio': ['L-alanyl-L-aspartate',
#    'L-alanyl-L-glutamine',
#    'L-alanyl-L-threonine',
#    'L-arginine',
#    'calcium(2+)',
#    'L-cysteinylglycine',
#    'Chloride',
#    'Co2+',
#    'Cu2+',
#    '1,4-Dihydroxy-2-naphthoate',
#    'Fe3+',
#    'Folate',
#    'D-glucose',
#    'L-glutamine',
#    'Glycyl-L-asparagine',
#    'Glycerol 3-phosphate',
#    'Gly-Cys',
#    'Glycylleucine',
#    'L-histidine',
#    'Hypoxanthine',
#    'L-isoleucine',
#    'potassium',
#    'L-leucine',
#    'L-lysine',
#    'L-Methionine Sulfoxide',
#    'magnesium',
#    'Mn2+',
#    'D-Mannitol',
#    'Menaquinone 7',
#    'NMN',
#    'O2',
#    'octadecanoate (n-C18:0)',
#    'L-phenylalanine',
#    'Protoheme',
#    '(R)-Pantothenate',
#    'L-proline',
#    'Pyridoxine',
#    'Ubiquinone-8',
#    'Riboflavin',
#    'L-serine',
#    'Siroheme',
#    'sulfate',
#    'Spermidine',
#    'Thiamin',
#    'L-tryptophan',
#    'L-tyrosine',
#    'uracil',
#    'L-valine',
#    'Xanthine',
#    'Zinc'],
#   'Tamaño_medio': 50,
#   'Crecimiento': 47.17813269771683}}

# %% [markdown]
# ## Nombres de las columnas

# %% [markdown]
# Los nombres de las columnas serán todos lo metabolitos diferentes que encontremos en los diferentes medios de todos los organismos.

# %%
metab_unique = [] #Lista de todos los metabolitos diferentes de todos los medios

for especie, info_especie in resultados.items():
    modelo = info_especie["Nombre"]
    medio = info_especie["Medio"]
    tamaño = info_especie["Tamaño_medio"]
    crecimiento = info_especie["Crecimiento"]
    for met in medio:
        if met not in metab_unique:
            metab_unique.append(met)

# %%
metab_unique
# Out:
# ['1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#  '4-hydroxybenzoate',
#  'Adenosine',
#  'L-alanyl-L-histidine',
#  'L-arginine',
#  'calcium(2+)',
#  'L-cysteinylglycine',
#  'Chloride',
#  'Co2+',
#  'Cu2+',
#  'Deoxyguanosine',
#  'Fe3+',
#  'D-glucose',
#  'Glycerol 3-phosphate',
#  'glycogen, structure 2 (glycogenin-1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#  'potassium',
#  'L-methionyl-L-alanine',
#  'magnesium',
#  'Mn2+',
#  'O2',
#  'Protoheme',
#  'Riboflavin',
#  'sulfate',
#  'Thiamin',
#  'aldehydo-D-xylose',
#  'Zinc',
#  'L-alanyl-L-threonine',
#  'cytosine',
#  'Fe2+',
#  'Glycyl-L-asparagine',
#  'L-lysine',
#  'Nicotinate',
#  'pectins',
#  'meso-2,6-Diaminoheptanedioate',
#  'L-alanyl-L-leucine',
#  'D-Glucosamine',
#  'Glycylleucine',
#  'Glycyl-L-tyrosine',
#  'hydrogenphosphate',
#  'Spermidine',
#  'L-alanyl-L-glutamine',
#  'Gly-Cys',
#  'Menaquinone 7',
#  '(R)-Pantothenate',
#  'Pyridoxal',
#  'Xanthine',
#  'Glycyl-L-glutamine',
#  'Glycyl-L-methionine',
#  'Guanine',
#  'Hypoxanthine',
#  'Nitrate',
#  'octadecanoate (n-C18:0)',
#  'Adenosylcobalamin',
#  'Larch arabinogalactan',
#  'L-Rhamnose',
#  'Cytidine',
#  'Siroheme',
#  'Adenine',
#  'Folate',
#  'Urea',
#  'starch, structure 1 (1,6-{7[1,4-Glc], 4[1,4-Glc]})',
#  'Taurine',
#  'N-acetyl-D-glucosamine',
#  'thiosulfate(2-)',
#  '4-Aminobenzoate',
#  'Resistant starch',
#  'Glycylphenylalanine',
#  'myo-inositol',
#  'Menaquinone 8',
#  'L-proline',
#  'Ubiquinone-8',
#  'Chicory inulin',
#  'L-tryptophan',
#  'uracil',
#  'GlcNAc-alpha-1,4-Core 2',
#  'L-alanyl-L-aspartate',
#  'Glycylproline',
#  'NMN',
#  'Putrescine',
#  'Inosine',
#  'Uridine',
#  'Amylopectin, 900 repeat units',
#  'L-serine',
#  'Dextrin',
#  'L-isoleucine',
#  'L-valine',
#  '2-Demethylmenaquinone 8',
#  'L-asparagine',
#  'L-cysteine',
#  'L-histidine',
#  'L-Methionine Sulfoxide',
#  'Ornithine',
#  'Orotate',
#  'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)',
#  'L-threonine',
#  'L-tyrosine',
#  'tetradecanoate (n-C14:0)',
#  'Thymidine',
#  'L-aspartate',
#  'Ammonium',
#  'L-phenylalanine',
#  '4-Amino-5-hydroxymethyl-2-methylpyrimidine',
#  'L-alanyl-L-glutamate',
#  'L-leucine',
#  'Pyridoxine',
#  'Biotin',
#  'L-methionine',
#  '2-Oxoglutarate',
#  'L-glutamate',
#  'L-glutamine',
#  'Citrate',
#  'D-glucitol',
#  'L-alanine',
#  'Oxidized glutathione',
#  '1,4-Dihydroxy-2-naphthoate',
#  'D-Mannitol']

# %% [markdown]
# ## Creación del Excel

# %%
# Crear un nuevo libro de Excel y seleccionar la hoja de trabajo
workbook = openpyxl.load_workbook("Desglose_Initial_Approach_Minimal.xlsx")
hoja = workbook.active

# Rellenamos por cada especie(fila):
# Columna 1 con el nombre del mejor modelo
# Columna 2 tamaño del medio
# Columna 3 crecimiento
# Columnas 4-n metabolitos del medio

#Añadimos los nombres de las n columnas de metabolitos
for i, met  in enumerate(metab_unique, start=4):
    hoja.cell(row=1, column=i, value=met)

#Rellenamos las columnas
for i, nombre  in enumerate(resultados.keys(), start=2):
    info_especie = resultados[nombre] #Diccionario de la especie
    hoja.cell(row=i, column=1, value=info_especie["Nombre"])
    hoja.cell(row=i, column=2, value=info_especie["Tamaño_medio"])
    hoja.cell(row=i, column=3, value=info_especie["Crecimiento"])
    #Recorremos las columnas de los metabolitos
    for j, met in enumerate(metab_unique, start=4):
        if met in info_especie["Medio"]:
            hoja.cell(row=i, column=j, value=1)
        else:
            hoja.cell(row=i, column=j, value=0)

# Guardar el libro de Excel
workbook.save('Desglose_Initial_Approach_Minimal.xlsx')

# %% [markdown]
# ## Organismos que consumen el máximo de sustratos

# %%
fuentes_C = ["glucose", "rhamnose", "xylose","glucuronic"]
better = {} #Especies que consumen dos azucares o más de la lista

for especie, info_modelo in resultados.items():
    medio = info_modelo["Medio"]
    conjunto = " ".join(medio).lower()
    consum = []
    n = 0
    for azucar in fuentes_C:
        if azucar in conjunto:
            n += 1
            consum.append(azucar)
    #Si consume 2 azúcares o más, añadir al diccionario
    if n >= 2:
        better[especie] = [n, consum]

# %%
for especie, info in better.items():
    if info[0] > 2:
        print(especie, " consume:", info[1])
# Out:
# Bifidobacterium_longum  consume: ['glucose', 'rhamnose', 'xylose']
# Bacillus_mojavensis  consume: ['glucose', 'rhamnose', 'xylose']
# Bifidobacterium_adolescentis  consume: ['glucose', 'rhamnose', 'xylose']
# Bifidobacterium_bifidum  consume: ['glucose', 'rhamnose', 'xylose']
# Bacillus_vallismortis  consume: ['glucose', 'rhamnose', 'xylose']
# Hafnia_alvei  consume: ['glucose', 'rhamnose', 'xylose']
